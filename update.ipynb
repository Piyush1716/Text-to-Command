# %%
import numpy as np
import pandas as pd

# %%
c = pd.read_csv('c.csv')
df  = pd.read_csv('commands.csv')

# %%
df.head()
# Out:
#                                           user_query    command  \
# 0  How do I run `htop` so it refreshes every 0.5 ...  htop -d 5
# 1  What's the command to start `htop` with a half...  htop -d 5
# 2  Could you give me the command to launch `htop`...  htop -d 5
# 3  I need to execute `htop` with a 0.5-second del...  htop -d 5
# 4    How can I get `htop` to refresh twice a second?  htop -d 5
#
#                                      description
# 0  Runs htop with a 0.5-second refresh interval.
# 1  Runs htop with a 0.5-second refresh interval.
# 2  Runs htop with a 0.5-second refresh interval.
# 3  Runs htop with a 0.5-second refresh interval.
# 4  Runs htop with a 0.5-second refresh interval.

# %%
swap_dict = {
    # --- File & Directory Management ---
    'pwd': 'cd',
    'ls': 'dir',
    'ls -la': 'dir /a',
    'ls -lh': 'dir',
    'ls -l': 'dir',
    'ls -R': 'dir /s',
    'cd ..': 'cd ..',
    'cd ~': 'cd %HOMEPATH%',
    'mkdir newdir': 'mkdir newdir',
    'mkdir -p /path/to/newdir': 'mkdir "C:\\path\\to\\newdir"',
    'rmdir empty_dir': 'rmdir empty_dir',
    'rm file.txt': 'del file.txt',
    'rm -r dir1': 'rmdir /s /q dir1',
    'rm -rf directory': 'rmdir /s /q directory',
    'cp file.txt /backup': 'copy file.txt C:\\backup\\',
    'cp -r dir1 dir2': 'xcopy dir1 dir2 /e /i',
    'mv oldname.txt newname.txt': 'rename oldname.txt newname.txt',
    'mv dir1 /archive': 'move dir1 C:\\archive\\',
    'touch newfile.txt': 'type nul > newfile.txt',
    'cat file.txt': 'type file.txt',
    'cat file1.txt file2.txt': 'type file1.txt file2.txt > combined.txt',
    'head -n 5 access.log': 'powershell -Command "Get-Content access.log -TotalCount 5"',
    'tail -n 10 error.log': 'powershell -Command "Get-Content error.log -Tail 10"',
    'tail -f error.log': 'powershell -Command "Get-Content error.log -Wait"',
    'stat file.txt': 'dir file.txt',
    'echo "text" > file.txt': 'echo text > file.txt',

    # --- Permissions & Ownership (limited in Windows) ---
    'chmod 755 script.sh': 'icacls script.sh /grant Everyone:F',
    'chmod +x script.sh': 'icacls script.sh /grant Everyone:F',
    'chown user:group file.txt': 'icacls file.txt /setowner user',
    'chown user file.txt': 'icacls file.txt /setowner user',

    # --- System Info ---
    'uname -a': 'systeminfo',
    'uname -r': 'ver',
    'uname -m': 'echo %PROCESSOR_ARCHITECTURE%',
    'df -h': 'wmic logicaldisk get size,freespace,caption',
    'free -m': 'wmic os get FreePhysicalMemory,TotalVisibleMemorySize /Format:List',
    'uptime': 'net stats srv',
    'top': 'tasklist',
    'htop': 'taskmgr',

    # --- Process Management ---
    'ps aux': 'tasklist',
    'ps -ef': 'tasklist',
    'kill -9 1234': 'taskkill /PID 1234 /F',
    'kill 1234': 'taskkill /PID 1234',
    'pkill nginx': 'taskkill /IM nginx.exe /F',

    # --- User Management ---
    'whoami': 'whoami',
    'id': 'whoami /user',
    'adduser newuser': 'net user newuser /add',
    'userdel -r testuser': 'net user testuser /delete',
    'passwd newuser': 'net user newuser *',
    'netstat -tulpn': 'netstat -ano',
    'ifconfig': 'ipconfig /all',
    'ping -c 4 google.com': 'ping google.com',
    'ping 8.8.8.8': 'ping 8.8.8.8',
    'traceroute google.com': 'tracert google.com',

    # --- Networking ---
    'ip addr show': 'ipconfig',
    'ss -tulwn': 'netstat -ano',
    'netstat -an': 'netstat -an',
    'ip link show': 'netsh interface show interface',
    'route -n': 'route print',

    # --- Disk & Hardware ---
    'lsblk': 'wmic logicaldisk get name,size,description',
    'lscpu': 'wmic cpu get name,numberofcores,numberoflogicalprocessors',
    'df /': 'wmic logicaldisk get size,freespace,caption',
    'du -sh /var/log': 'powershell -Command "Get-ChildItem C:\\Windows\\Logs -Recurse | Measure-Object -Sum Length"',

    # --- Package Management (APT/YUM/DNF → Chocolatey or Winget) ---
    'apt update': 'choco upgrade all -y',
    'apt install nginx': 'choco install nginx -y',
    'apt remove nginx': 'choco uninstall nginx -y',
    'yum install httpd': 'choco install apache-httpd -y',
    'dnf install python3': 'choco install python -y',

    # --- Miscellaneous ---
    'clear': 'cls',
    'history': 'doskey /history',
    'date': 'date /t',
    'time': 'time /t',
    'echo $PATH': 'echo %PATH%',
    'exit': 'exit'
}

# %%
df["windows"] = df["command"].map(swap_dict).fillna(df["command"])
print(df)
# Out:
#                                              user_query  \
# 0     How do I run `htop` so it refreshes every 0.5 ...
# 1     What's the command to start `htop` with a half...
# 2     Could you give me the command to launch `htop`...
# 3     I need to execute `htop` with a 0.5-second del...
# 4       How can I get `htop` to refresh twice a second?
# ...                                                 ...
# 7387               Initiate two pings to the IP address
# 7388   Show me the command to send two ping requests to
# 7389  I want to confirm if 192.168.1.1 is reachable....
# 7390  Perform a `ping` to 192.168.1.1, limit it to t...
# 7391                Go ahead and ping 192.168.1.1 twice
#
#                     command  \
# 0                 htop -d 5
# 1                 htop -d 5
# 2                 htop -d 5
# 3                 htop -d 5
# 4                 htop -d 5
# ...                     ...
# 7387  ping -c 2 192.168.1.1
# 7388  ping -c 2 192.168.1.1
# 7389  ping -c 2 192.168.1.1
# 7390  ping -c 2 192.168.1.1
# 7391  ping -c 2 192.168.1.1
#
#                                             description                windows
# 0         Runs htop with a 0.5-second refresh interval.              htop -d 5
# 1         Runs htop with a 0.5-second refresh interval.              htop -d 5
# 2         Runs htop with a 0.5-second refresh interval.              htop -d 5
# 3         Runs htop with a 0.5-second refresh interval.              htop -d 5
# 4         Runs htop with a 0.5-second refresh interval.              htop -d 5
# ...                                                 ...                    ...
# 7387  Sends 2 ICMP echo requests to the IP 192.168.1.1.  ping -c 2 192.168.1.1
# 7388  Sends 2 ICMP echo requests to the IP 192.168.1.1.  ping -c 2 192.168.1.1
# 7389  Sends 2 ICMP echo requests to the IP 192.168.1.1.  ping -c 2 192.168.1.1
# 7390  Sends 2 ICMP echo requests to the IP 192.168.1.1.  ping -c 2 192.168.1.1
# 7391  Sends 2 ICMP echo requests to the IP 192.168.1.1.  ping -c 2 192.168.1.1
#
# [7392 rows x 4 columns]

# %%
import pandas as pd
import torch
from sentence_transformers import SentenceTransformer, util

# Load dataset
# df = pd.read_csv("commands.csv")

# Use user queries directly
queries_list = df['user_query'].tolist()
commands_list = df['windows'].tolist()

# Load semantic model
model = SentenceTransformer('multi-qa-mpnet-base-dot-v1')

# Encode all queries
query_embeddings = model.encode(queries_list, convert_to_tensor=True)

def get_best_command(user_input, top_k=3):
    input_emb = model.encode(user_input, convert_to_tensor=True)
    scores = util.cos_sim(input_emb, query_embeddings)[0]
    top_results = torch.topk(scores, k=len(scores))  # check all scores

    seen_commands = set()
    matches = []

    for score, idx in zip(top_results[0], top_results[1]):
        cmd = commands_list[idx]
        if cmd not in seen_commands:
            matches.append({
                "user_query": queries_list[idx],
                "command": cmd,
                "score": float(score)
            })
            seen_commands.add(cmd)
        if len(matches) >= top_k:
            break

    return matches

# Test
test_queries = [
    "show me all files in this folder with details",
    "open file.txt in read only mode using vim",
    "how to refresh htop every half second",
    "remove unused dependencies in fedora"
    
]

for q in test_queries:
    print(f"\nQuery: {q}")
    results = get_best_command(q)
    for r in results:
        print(f"  → {r['command']} (matched '{r['user_query']}') score={r['score']:.4f}")
# Out:
# Query: show me all files in this folder with details
#   → ls -d */ (matched 'Show me only the directories in this folder') score=0.7997
#   → dir /s (matched 'Show me all files and directories, including those nested within others') score=0.7784
#   → dir /a (matched 'I need to see everything in this folder, including dot files, with their full attributes') score=0.7776
#
# Query: open file.txt in read only mode using vim
#   → vim -R file.txt (matched 'Open file.txt in Vim in read-only mode') score=0.9893
#   → vim file.txt (matched 'Please open file.txt using Vim') score=0.8068
#   → vim -u NONE file.txt (matched 'Run Vim on `file.txt` in a clean mode, ignoring `.vimrc`') score=0.7464
#
# Query: how to refresh htop every half second
#   → htop -d 5 (matched 'How do I run `htop` so it refreshes every 0.5 seconds?') score=0.9170
#   → taskmgr (matched 'Execute the htop command') score=0.6853
#   → htop -u user (matched 'Monitor processes for 'user' using `htop`') score=0.6008
#
# Query: remove unused dependencies in fedora
#   → dnf autoremove (matched 'How do I remove unused dependencies on Fedora?') score=0.9743
#   → apt autoremove (matched 'What's the command to clean up unused dependencies?') score=0.7786
#   → dnf repoquery --installed (matched 'Please list every package installed on this Fedora system') score=0.6638

# %%
test_queries = [
    "list all files in the current directory with sizes and permissions",
    "show hidden files too when listing directory contents",
    "display the disk usage of each folder in the current directory",
    "check how much free memory I have right now",
    "see running processes sorted by CPU usage",
    "find out my current working directory",
    "show the current system date and time",
    "display the first 10 lines of a file named log.txt",
    "count how many lines are in file.txt",
    "search for the word 'error' in system.log file",
    "show only the lines that contain 'python' in a file",
    "copy file.txt to the backup folder",
    "move all .log files to the logs directory",
    "remove a directory named temp along with its contents",
    "create a new directory called projects",
    "display the last 20 lines of messages.log file",
    "find all .py files in the current folder and subfolders",
    "change file permissions to make script.sh executable",
    "compress the backup folder into backup.tar.gz",
    "extract files from archive.tar.gz into current directory",
    "show network configuration details of my system",
    "display the IP address of my device",
    "ping google.com five times to check connectivity",
    "install nginx web server using apt",
    "update all installed packages on my ubuntu system",
    "remove apache2 from my system completely",
    "clean up unused packages and dependencies",
    "display all active network connections",
    "show currently logged in users",
    "reboot the system immediately"
]

for q in test_queries:
    print(f"\nQuery: {q}")
    results = get_best_command(q)
    for r in results:
        print(f"  → {r['command']} (matched '{r['user_query']}') score={r['score']:.4f}")
# Out:
# Query: list all files in the current directory with sizes and permissions
#   → dir (matched 'List files with their permissions and human-readable sizes') score=0.8393
#   → dir /a (matched 'Could you run the command to list all files with their sizes, permissions, and modification dates?') score=0.8242
#   → ls -S (matched 'List files by size') score=0.7761
#
# Query: show hidden files too when listing directory contents
#   → dir /a (matched 'Display the contents of the current directory, showing hidden files and detailed information') score=0.8109
#   → dir /s (matched 'How do I list files in subdirectories as well?') score=0.6548
#   → ls -d */ (matched 'Show me only the directories in this folder') score=0.6546
#
# Query: display the disk usage of each folder in the current directory
#   → wmic logicaldisk get size,freespace,caption (matched 'Show me the disk usage for the root filesystem') score=0.7868
#   → findmnt -D (matched 'I need to see the disk usage for all currently mounted filesystems') score=0.7822
#   → df -t ext4 (matched 'Please show me the disk usage for all ext4 filesystems') score=0.7545
#
# Query: check how much free memory I have right now
#   → wmic os get FreePhysicalMemory,TotalVisibleMemorySize /Format:List (matched 'Check the memory status') score=0.8213
#   → free -t (matched 'Show me the total memory usage') score=0.8004
#   → free -w (matched 'Run the `free` command to display wide memory usage') score=0.7882
#
# Query: see running processes sorted by CPU usage
#   → tasklist (matched 'Show me all running processes with full details') score=0.7528
#   → iotop -o (matched 'How do I display processes that are currently performing I/O?') score=0.7190
#   → lscpu -e (matched 'How do I view my system's CPU details in a table?') score=0.7137
#
# Query: find out my current working directory
#   → cd (matched 'I need to know my current directory') score=0.8972
#   → pwd -L (matched 'I need to know my current directory, as seen by the shell') score=0.8648
#   → pwd -P (matched 'Show me the absolute physical path of my current working directory') score=0.8116
#
# Query: show the current system date and time
#   → watch -n 1 'date' (matched 'How can I get a real-time display of the system date that refreshes?') score=0.7769
#   → systeminfo (matched 'Please display all system information') score=0.7285
#   → dmidecode -t system (matched 'Display the system hardware information') score=0.6941
#
# Query: display the first 10 lines of a file named log.txt
#   → cut -c 1-10 file.txt (matched 'How can I display just the first 10 characters of lines in file.txt?') score=0.8466
#   → head -v access.log (matched 'How can I display the first 10 lines of `access.log` and include a file header?') score=0.8007
#   → powershell -Command "Get-Content error.log -Tail 10" (matched 'Display the tail end of `error.log`, specifically 10 lines') score=0.7917
#
# Query: count how many lines are in file.txt
#   → wc -l file.txt (matched 'How do I count the number of lines in `file.txt`?') score=0.9617
#   → wc -w file.txt (matched 'I need to find out how many words are in file.txt') score=0.8525
#   → wc -c file.txt (matched 'How do I count the bytes in `file.txt`?') score=0.8314
#
# Query: search for the word 'error' in system.log file
#   → logger 'Test message' (matched 'Run the command `logger 'Test message'`') score=0.6904
#   → journalctl -p 3 -b (matched 'I'm looking for any problems reported in the logs since the system started up. What command should I use?') score=0.6866
#   → tail -n +2 error.log (matched 'Could you please print `error.log`, commencing from the second line?') score=0.6722
#
# Query: show only the lines that contain 'python' in a file
#   → look word file.txt (matched 'Show me the lines in `file.txt` that start with "word"') score=0.7218
#   → cat -v file.txt (matched 'Show me the contents of `file.txt`, including any hidden characters') score=0.5928
#   → comm -12 file1.txt file2.txt (matched 'How can I filter file1.txt and file2.txt to show only their shared lines?') score=0.5892
#
# Query: copy file.txt to the backup folder
#   → copy file.txt C:\backup\ (matched 'Copy `file.txt` to `/backup`') score=0.9340
#   → cp -v file.txt /backup (matched 'Execute the command to copy file.txt to the /backup directory, verbosely') score=0.8657
#   → cp -u file.txt /backup (matched 'Can you help me copy `file.txt` to `/backup` without overwriting an existing file unless it's older?') score=0.8485
#
# Query: move all .log files to the logs directory
#   → cd /var/log (matched 'Move into the `/var/log` directory') score=0.7972
#   → pushd /var/log (matched 'Could you move me to `/var/log` and push my current working directory?') score=0.7124
#   → find /var -name '*.log' (matched 'I need to track down all .log files residing in /var') score=0.7049
#
# Query: remove a directory named temp along with its contents
#   → rmdir /s /q dir1 (matched 'How do I remove `dir1` and all its contents?') score=0.7262
#   → rmdir /s /q directory (matched 'Delete `directory` and all its contents, forcefully') score=0.7222
#   → cd /tmp (matched 'Change my current directory to /tmp') score=0.6530
#
# Query: create a new directory called projects
#   → mkdir newdir (matched 'Please create a directory named `newdir`') score=0.7039
#   → mkdir "C:\path\to\newdir" (matched 'How do I create the directory `/path/to/newdir` and any necessary parent directories?') score=0.6164
#   → cd .. (matched 'Change directory to the one above this') score=0.6057
#
# Query: display the last 20 lines of messages.log file
#   → powershell -Command "Get-Content error.log -Tail 10" (matched 'How do I display the final 10 lines of `error.log`?') score=0.7809
#   → head -n 20 access.log (matched 'Display the first twenty lines of access.log') score=0.7540
#   → tail -c 100 error.log (matched 'Display the final 100 bytes from the error.log file') score=0.7283
#
# Query: find all .py files in the current folder and subfolders
#   → ls -d */ (matched 'List all directories in the current directory') score=0.6721
#   → dir /s (matched 'How do I list all files and subdirectories recursively?') score=0.6703
#   → dnf repoquery --requires python3 (matched 'List all packages required by python') score=0.5721
#
# Query: change file permissions to make script.sh executable
#   → icacls script.sh /grant Everyone:F (matched 'Set `script.sh`'s permissions so I can run it') score=0.8912
#   → chmod u+x script.sh (matched 'I need to grant execute permissions for `script.sh` to the file owner') score=0.8530
#   → chmod g-x script.sh (matched 'How do I change `script.sh` permissions to deny group execute?') score=0.7880
#
# Query: compress the backup folder into backup.tar.gz
#   → restore -rf backup.tar (matched 'I need to restore the filesystem from `backup.tar`') score=0.6862
#   → tar --acls --xattrs -cpf backup.tar /data (matched 'I want to package the `/data` directory into `backup.tar`, retaining all its metadata like ACLs and extended attributes') score=0.6475
#   → cp -a dir1 /backup (matched 'What command should I use to archive `dir1` to `/backup`?') score=0.6454
#
# Query: extract files from archive.tar.gz into current directory
#   → cp -a dir1 /backup (matched 'How do I perform an archive copy of the directory `dir1` to the `/backup` location?') score=0.6304
#   → move dir1 C:\archive\ (matched 'How can I get `dir1` into the `/archive` path?') score=0.6147
#   → mv -u dir1 /archive (matched 'Can you get `dir1` into `/archive`? Just move it if the `dir1` I'm providing is newer, or if there's no `dir1` in `/archive` yet') score=0.5840
#
# Query: show network configuration details of my system
#   → ipconfig (matched 'Show me my network interface details') score=0.8454
#   → ipconfig /all (matched 'I want to view the network configuration') score=0.8386
#   → netsh interface show interface (matched 'Show me my network interface configuration') score=0.8333
#
# Query: display the IP address of my device
#   → ipconfig /all (matched 'How do I display my IP address?') score=0.8629
#   → ipconfig (matched 'How do I see my IP address?') score=0.8120
#   → ipset list (matched 'Can you display the IP sets?') score=0.7022
#
# Query: ping google.com five times to check connectivity
#   → ping google.com (matched 'Run the command to ping google.com four times') score=0.8333
#   → ping -s 100 google.com (matched 'Could you check google.com's reachability by pinging it with 100-byte packets?') score=0.7167
#   → ping 8.8.8.8 (matched 'I need to test connectivity to Google's DNS server') score=0.6970
#
# Query: install nginx web server using apt
#   → choco install nginx -y (matched 'Please use apt to install nginx') score=0.9002
#   → apt source nginx (matched 'Could you use apt to download the Nginx source?') score=0.8241
#   → apt search nginx (matched 'Perform an apt search for "nginx"') score=0.7998
#
# Query: update all installed packages on my ubuntu system
#   → apt upgrade (matched 'How do I update all my installed software?') score=0.8325
#   → choco upgrade all -y (matched 'I need to update my system's package repositories') score=0.8198
#   → dnf update (matched 'I want to update my packages') score=0.8121
#
# Query: remove apache2 from my system completely
#   → yum remove httpd (matched 'Please remove Apache from my system') score=0.8875
#   → choco install apache-httpd -y (matched 'I want to install Apache') score=0.6699
#   → yum reinstall httpd (matched 'Reinstall httpd on this system') score=0.6505
#
# Query: clean up unused packages and dependencies
#   → apt autoremove (matched 'What's the command to clean up unused dependencies?') score=0.8812
#   → dnf autoremove (matched 'Clean out old dependencies that are no longer needed after software removals') score=0.8638
#   → apt clean (matched 'Can you clean up the apt package directory?') score=0.7554
#
# Query: display all active network connections
#   → netstat -an (matched 'I want to see all active network connections and ports') score=0.8732
#   → ss -anp (matched 'Show me every active network connection along with its associated process ID') score=0.8422
#   → netsh interface show interface (matched 'Display active network links') score=0.8293
#
# Query: show currently logged in users
#   → w (matched 'Show me who is currently logged in') score=0.8746
#   → who (matched 'Show me the current users') score=0.8335
#   → who -H (matched 'Show me the currently logged-in users, including column headers') score=0.8137
#
# Query: reboot the system immediately
#   → apt clean (matched 'Run `apt clean`') score=0.7137
#   → debugfs -c /dev/sda1 (matched 'Please run `debugfs -c /dev/sda1`') score=0.7122
#   → dnf autoremove (matched 'Could you run the dependency cleanup command?') score=0.7047

# %%
model.save("saved_model_2")        # save
torch.save(query_embeddings, "query_embeddings_2.pt")  # save
torch.save(commands_list, "commands_list_2.pt")   # save the list too

# %%
test_queries = [
    "copy file.txt to the backup folder",
    "move all .log files to logs directory",
    "rename oldfile.txt to newfile.txt",
    "delete temp.txt permanently",
    "remove directory named temp along with its contents",
    "create a new folder called projects",
    "duplicate all files in folder1 to folder2",
    "replace all occurrences of 'foo' with 'bar' in file.txt"
]
for q in test_queries:
    print(f"\nQuery: {q}")
    results = get_best_command(q)
    for r in results:
        print(f"  → {r['command']} (matched '{r['user_query']}') score={r['score']:.4f}")
# Out:
# Query: copy file.txt to the backup folder
#   → copy file.txt C:\backup\ (matched 'Copy `file.txt` to `/backup`') score=0.9340
#   → cp -v file.txt /backup (matched 'Execute the command to copy file.txt to the /backup directory, verbosely') score=0.8657
#   → cp -u file.txt /backup (matched 'Can you help me copy `file.txt` to `/backup` without overwriting an existing file unless it's older?') score=0.8485
#
# Query: move all .log files to logs directory
#   → cd /var/log (matched 'Move into the `/var/log` directory') score=0.7880
#   → pushd /var/log (matched 'Could you move me to `/var/log` and push my current working directory?') score=0.7147
#   → find /var -name '*.log' (matched 'I need to track down all .log files residing in /var') score=0.7036
#
# Query: rename oldfile.txt to newfile.txt
#   → rename oldname.txt newname.txt (matched 'What command should I use to rename `oldname.txt`'s filename to `newname.txt`?') score=0.8807
#   → ln file1.txt file2.txt (matched 'Please show me how to hard link `file1.txt` to a new name, `file2.txt`') score=0.7247
#   → cp file.txt file.bak (matched 'How can I make an identical copy of file.txt and name it file.bak?') score=0.7115
#
# Query: delete temp.txt permanently
#   → del file.txt (matched 'Delete file.txt') score=0.8085
#   → rm -f file.txt (matched 'Can you just delete file.txt for me?') score=0.7738
#   → rm -i file.txt (matched 'Can you safely delete file.txt for me?') score=0.7420
#
# Query: remove directory named temp along with its contents
#   → rmdir /s /q dir1 (matched 'How do I remove `dir1` and all its contents?') score=0.7245
#   → rmdir /s /q directory (matched 'Delete `directory` and all its contents, forcefully') score=0.7070
#   → cd /tmp (matched 'Change my current directory to /tmp') score=0.6677
#
# Query: create a new folder called projects
#   → mkdir newdir (matched 'Can you make a new folder called `newdir`?') score=0.6974
#   → mkdir "C:\path\to\newdir" (matched 'How do I create the directory `/path/to/newdir` and any necessary parent directories?') score=0.5803
#   → cd /usr/share (matched 'Go to `/usr/share`') score=0.5765
#
# Query: duplicate all files in folder1 to folder2
#   → xcopy dir1 dir2 /e /i (matched 'What's the command to copy an entire folder, including its contents, from dir1 to dir2?') score=0.7701
#   → cp -a dir1 /backup (matched 'Please tell me the command to copy the entire `dir1` directory to `/backup` and preserve everything') score=0.6680
#   → paste file1.txt file2.txt (matched 'Is there a command that takes `file1.txt` and `file2.txt` and pastes them together side-by-side?') score=0.6028
#
# Query: replace all occurrences of 'foo' with 'bar' in file.txt
#   → expand file.txt (matched 'I need to replace all tabs with spaces in `file.txt`. What's the command?') score=0.6549
#   → unexpand file.txt (matched 'I need to replace spaces with tabs in `file.txt`. What's the command?') score=0.6363
#   → rename oldname.txt newname.txt (matched 'Give me the command to rename `oldname.txt` as `newname.txt`') score=0.6347

# %%
df['windows'].drop_duplicates().values
# Out:
# array(['htop -d 5', 'vim -R file.txt', 'nano -c config.conf', 'cd /etc',
#        'ls -1', 'cp -u file.txt /backup', 'mv -n file.txt /tmp',
#        'rm -v file.txt', 'cat << EOF > script.sh', 'less -i logfile.txt',
#        'head -n -5 access.log', 'tail -q -n 3 file1.txt file2.txt',
#        'uname -n', 'df -i', 'chmod -R 750 /data', 'chown :group file.txt',
#        'apt clean', 'yum check-update', 'dnf autoremove',
#        'ping -c 2 192.168.1.1', 'ifconfig eth0 down', 'netstat -r', 'w',
#        'usermod -aG sudo newuser', 'groupadd newgroup', 'ps -u user',
#        'pkill -u user', 'htop -t', "vim -c 'set number' file.txt",
#        'nano -w config.conf', 'cd /usr/local/bin', 'ls -S',
#        'cp -v file.txt /backup', 'mv -u dir1 /archive',
#        'touch -a file.txt', 'cat -s file.txt', 'less -M logfile.txt',
#        'head -q -n 2 file1.txt file2.txt', 'tail -v -n 2 error.log',
#        'free -s 2', 'chmod u+x script.sh', 'chown -R user:group /var/www',
#        'apt list --installed', 'yum history', 'dnf provides /bin/bash',
#        'ping -s 100 google.com', 'netstat -s', 'last', 'ps -p 1234',
#        'vim -b file.bin', 'cd /tmp', 'ls -F', 'pwd -L', 'ls -X',
#        'cd /usr/share', 'ls --color=auto', 'ls -i', 'cd ~user', 'ls -r',
#        'ls -d */', 'cp -a dir1 /backup', 'mv -b file.txt /tmp',
#        'rm -f file.txt', 'touch -c file.txt', 'mkdir -m 700 secure_dir',
#        'cp -l file1.txt file2.txt', 'mv -f file.txt /tmp',
#        'rmdir empty_dir', 'touch -m file.txt', 'cp -s file1.txt link.txt',
#        'cat -b file.txt', 'less -S logfile.txt', 'head -v access.log',
#        'tail -c 100 error.log', 'cat -e file.txt', 'less -r logfile.txt',
#        'head -n 3 file1.txt file2.txt', 'tail -n 0 -f error.log',
#        'cat -t file.txt', 'less -u logfile.txt', 'net stats srv',
#        'vmstat 2 5', 'iostat -x 1 3',
#        'wmic cpu get name,numberofcores,numberoflogicalprocessors',
#        'wmic logicaldisk get name,size,description',
#        'dmidecode -t memory', 'chmod g+w file.txt',
#        'icacls file.txt /setowner user', 'chmod o-r file.txt',
#        'chown -R :group /data', 'apt search nginx', 'yum info httpd',
#        'dnf clean all', 'apt show python3',
#        "yum groupinstall 'Development Tools'",
#        'dnf repoquery --installed', 'apt depends nginx',
#        'yum provides /usr/bin/python3', 'dnf group list',
#        'apt policy nginx', 'cd /var/log', 'cd', 'dir /a',
#        'copy file.txt C:\\backup\\', 'rename oldname.txt newname.txt',
#        'rmdir /s /q directory', 'type nul > newfile.txt',
#        'mkdir "C:\\path\\to\\newdir"', 'cat logfile.txt',
#        'less largefile.txt',
#        'powershell -Command "Get-Content access.log -TotalCount 5"',
#        'powershell -Command "Get-Content error.log -Tail 10"',
#        'systeminfo', 'tasklist',
#        'wmic logicaldisk get size,freespace,caption',
#        'wmic os get FreePhysicalMemory,TotalVisibleMemorySize /Format:List',
#        'icacls script.sh /grant Everyone:F', 'choco upgrade all -y',
#        'choco install nginx -y', 'yum update', 'choco install python -y',
#        'ping google.com', 'ipconfig /all', 'netstat -ano', 'whoami',
#        'whoami /user', 'net user newuser /add', 'taskkill /PID 1234 /F',
#        'ipconfig', 'arp -n', 'route print',
#        'netsh interface show interface', 'ss -anp', 'tracert google.com',
#        'who -b', "usermod -c 'Full Name' user", 'groupdel oldgroup',
#        'passwd -l user', 'chage -E 2025-12-31 user', 'finger user',
#        'nice -n 10 command', 'renice 5 1234', 'top -u user', 'pstree -p',
#        'kill -SIGTERM 1234', 'pgrep nginx', 'emacs file.txt',
#        'vim -o file1.txt file2.txt', 'nano -B config.conf',
#        'emacs -nw file.txt', 'lsblk -f', 'lscpu -e', 'vmstat -s',
#        'chmod g-x script.sh', 'chown -hR user symlink', 'ip route show',
#        'ss -tuln', 'ln -s /etc/config.conf link.conf',
#        'ln file1.txt file2.txt', 'cat -v file.txt', 'less -X logfile.txt',
#        'who -u', 'chage -l user', 'top -b -n 1', 'pkill -9 nginx',
#        'vim -O file1.txt file2.txt', 'nano -E config.conf',
#        'powershell -Command "Get-ChildItem C:\\Windows\\Logs -Recurse | Measure-Object -Sum Length"',
#        "find /var -name '*.log'", 'lsmod', 'uname -o',
#        'chmod 600 file.txt', 'chown -v user file.txt',
#        'ip addr add 192.168.1.101/24 dev eth0', 'passwd -u user',
#        'kill -SIGKILL 1234', 'emacs --no-init-file file.txt',
#        'pushd /var/log', 'popd', 'dirs -v', 'lsattr file.txt',
#        'chattr +i file.txt', 'setfacl -m u:user:rw file.txt',
#        'getfacl file.txt', 'zcat logfile.gz', 'zless logfile.gz',
#        'od -c file.bin', 'strings /bin/ls', 'hexdump -C file.bin',
#        'dir file.txt', 'lsof -i :80', 'tcpdump -i eth0',
#        'nslookup google.com', 'dig google.com', 'ipcs -m', 'sar -u 1 3',
#        'dmesg -T', 'lsdev', 'chgrp group file.txt',
#        'chgrp -R group /data', 'setfacl -b file.txt', 'apt source nginx',
#        'yum reinstall httpd', 'dnf history list', "logger 'Test message'",
#        'who -r', "chfn -f 'Full Name' user", 'newgrp group',
#        'at now + 1 hour', 'crontab -l', 'nohup command &',
#        'journalctl -u nginx', 'file file.bin', 'mkfifo pipe',
#        'truncate -s 1M file.txt', 'split -b 1M largefile.txt',
#        'fmt -w 80 file.txt', 'nl file.txt', 'wc -l file.txt',
#        'tac file.txt', 'ethtool eth0', 'ipset list', 'iptables -L -v',
#        'ulimit -n 1024', 'semanage fcontext -l', 'restorecon -v /var/log',
#        'getsebool -a', "watch -n 1 'date'", 'time command', 'batch',
#        'disown -h %1', 'jobs -l', 'fg %1', 'vmstat -d',
#        'dmidecode -t bios', 'colrm 1 5 < file.txt', 'expand file.txt',
#        'unexpand file.txt', "cut -d ',' -f 1 file.csv", 'tee file.txt',
#        'shred -u file.txt', 'mknod /dev/mynode c 1 3',
#        'fuser -v /var/log/syslog', 'ltrace -p 1234', 'strace -p 1234',
#        'mtr google.com', 'nmap localhost', 'host google.com',
#        'chsh -s /bin/zsh user', 'id -Gn user', 'getent passwd user',
#        'pr -t file.txt', 'fold -w 80 file.txt', 'sort file.txt',
#        'uniq file.txt', 'comm file1.txt file2.txt', 'df -t ext4',
#        'free -w', 'lscpu -b', 'chcon -t httpd_sys_content_t /var/www',
#        'setsebool -P httpd_enable_homedirs on', 'chattr -i file.txt',
#        'install -m 755 script.sh /usr/local/bin', 'arping 192.168.1.1',
#        'ip neighbor show', 'atq', 'bg %1', 'nano +10 config.conf',
#        'vim -u NONE file.txt', 'emacs --batch -l script.el',
#        'wc -w file.txt', 'wc -c file.txt', 'paste file1.txt file2.txt',
#        'join file1.txt file2.txt', 'lsblk -o NAME,SIZE,TYPE', 'who -H',
#        'timeout 10s command', 'taskmgr', 'vim file.txt',
#        'nano config.conf', 'cd %HOMEPATH%', 'dir /s',
#        'xcopy dir1 dir2 /e /i', 'move dir1 C:\\archive\\', 'del file.txt',
#        'type file1.txt file2.txt > combined.txt', 'less -N logfile.txt',
#        'head access.log',
#        'powershell -Command "Get-Content error.log -Wait"', 'ver',
#        'free -h', 'chown -R user:group /data', 'apt upgrade',
#        'choco install apache-httpd -y', 'dnf update', 'ping 8.8.8.8',
#        'netstat -an', 'id newuser',
#        'adduser --home /home/testuser testuser', 'taskkill /PID 1234',
#        'htop -u user', 'vim +10 file.txt', 'pushd +2', 'dirs -c',
#        'cd -P /path/to/symlink', 'findmnt -t ext4', 'lsns', 'sysctl -a',
#        'auditctl -l', 'ausearch -m LOGIN', 'blkid -o list', 'iotop -o',
#        'setfacl -R -m u:user:rx /data', 'setfacl -x u:user file.txt',
#        'chcon -R -t user_home_t /home/user', 'semanage user -l',
#        'getfattr -d file.txt',
#        "setfattr -n user.comment -v 'Test' file.txt",
#        'chattr +a file.txt', 'dump -f backup.tar /dev/sda1',
#        'restore -rf backup.tar',
#        "xfs_quota -x -c 'limit bsoft=1g bhard=2g user' /mnt",
#        'tar --acls --xattrs -cpf backup.tar /data',
#        'dd if=/dev/zero of=file.img bs=1M count=100',
#        'zcmp file1.gz file2.gz', 'zdiff file1.gz file2.gz',
#        'xxd -r -p hexdump.txt file.bin', 'base64 file.bin',
#        'base64 -d encoded.txt', 'od -t x4 file.bin', 'zmore logfile.gz',
#        'tcpdump -i eth0 port 80', 'nft list ruleset', 'iptraf-ng -i eth0',
#        'hping3 -S 192.168.1.1', 'netcat -zv 192.168.1.1 22',
#        'ipset create myset hash:ip', 'tshark -i eth0 -c 10',
#        'pwgen -s 16 1', 'addgroup --gid 2000 newgroup',
#        'usermod -e 2025-12-31 user', 'lastlog', 'faillog -u user',
#        'crontab -u user -l', 'systemctl status nginx', 'pidstat -w 1 3',
#        'lscgroup', 'ionice -c3 command', 'taskset -cp 0-3 1234',
#        'journalctl -b', 'parted -l', 'apt-file search /usr/bin/nginx',
#        'yum deplist httpd', 'dnf module list', 'xxd file.bin',
#        'rsync -av /src /dst', "debugfs -R 'stat /file.txt' /dev/sda1",
#        'fsck.ext4 -n /dev/sda1', 'inotifywait -m /var/log',
#        'lsof -p 1234', 'pmap -x 1234', 'netstat -s | grep Tcp',
#        'ip -s link', 'semanage port -l',
#        'auditctl -a always,exit -F path=/etc/passwd -F perm=wa',
#        'sysdig -c netstat', 'dstat -cdngy', 'fatrace',
#        'cryptsetup luksOpen /dev/sdb1 crypt', 'badblocks -v /dev/sdb',
#        'ltrace -S -p 1234', 'strace -c -p 1234', 'gdb --pid 1234',
#        'perf stat -p 1234', 'nmap -sV 192.168.1.1', 'etckeeper init',
#        "etckeeper commit 'Updated config'", 'who -T',
#        'useradd -m -s /bin/zsh newuser', 'getent group sudo', 'pwck',
#        'grpck', 'col -b < file.txt', 'tsort file.txt',
#        'look word file.txt', 'tee -a file.txt',
#        'split -l 1000 file.txt prefix-', "csplit file.txt '/^#/' {*}",
#        'systemctl cat nginx', 'logrotate -f /etc/logrotate.conf',
#        'lscpu -p', 'numactl --hardware', 'ipcs -s', 'ipcs -q',
#        'dmidecode -t processor', 'semanage login -l',
#        'semanage boolean -l', 'netcat -l 12345',
#        "watch -d 'netstat -tuln'",
#        'emacs --eval \'(find-file "file.txt")\'', 'vim -es -S script.vim',
#        'nano -T 4 config.conf', 'cd /proc/$$', 'dirs -p', 'pushd -n /tmp',
#        'cd /dev/shm', "tree -if --noreport /etc | grep '.conf$'", 'sync',
#        'fallocate -l 1G file.img', 'xfs_info /dev/sda1',
#        'mkfs.btrfs /dev/sdb1', 'btrfs filesystem show',
#        'chattr +s file.txt', 'ionice -c2 -p 1234',
#        'prlimit --pid 1234 --nofile=1024', 'pidof nginx',
#        'bpftrace -e \'tracepoint:syscalls:sys_enter_openat { printf("%s opened %s\n", comm, str(args->filename)); }\'',
#        'lsof -iTCP -sTCP:LISTEN', 'ip monitor', 'ss -H -o',
#        'ip link set eth0 mtu 9000', 'nping --tcp -p 80 192.168.1.1',
#        'ipset add myset 192.168.1.100', 'tcpflow -i eth0 port 80',
#        "ngrep -q 'HTTP' port 80", 'bmon -i eth0', 'iftop -i eth0',
#        'hexdump -ve \'/1 "%02x"\' file.bin', 'strings -n 10 /bin/ls',
#        'rev file.txt', "csplit -z file.txt '/^#/' {*}", 'znew logfile.gz',
#        'xfs_repair /dev/sda1', 'btrfs subvolume create /mnt/subvol',
#        'btrfs scrub start /mnt', 'e2fsck -n /dev/sda1',
#        'tune2fs -l /dev/sda1', 'cryptsetup benchmark',
#        'setfacl -d -m u:user:rwx /data',
#        "semanage fcontext -a -t httpd_sys_content_t '/var/www(/.*)?'",
#        'chattr -R +u /backup', 'getfattr -n security.selinux file.txt',
#        'semanage port -a -t http_port_t -p tcp 8080', 'aa-status',
#        'apparmor_parser -R /etc/apparmor.d/usr.sbin.nginx',
#        'ausyscall --dump', 'lsipc', 'slabtop', 'lslogins', 'pwconv',
#        'grpconv', 'chage -M 90 user', 'last -x', 'authconfig --test',
#        'nscd -i passwd', 'atrm 1', 'systemd-cgtop', 'sar -n DEV 1 3',
#        'ethtool -S eth0', 'ip rule show', 'ip xfrm state',
#        'ip mroute show', 'tc qdisc show', 'bridge link show',
#        'ip netns list', 'ip netns exec ns1 ip addr',
#        'ncat --ssl 192.168.1.1 443', 'zstd -z file.txt',
#        'zstdcat file.txt.zst', 'xz -z file.txt', 'xzcat file.txt.xz',
#        'lzip -z file.txt', 'lzcat file.txt.lz', 'hexedit file.bin',
#        'nano -r 80 config.conf', 'emacs -Q file.txt', 'apt-config dump',
#        'yum history info 1', 'dnf repoquery --requires python3',
#        'rpm -qf /usr/bin/nginx', 'rpm -V nginx', 'debsums -c nginx',
#        'partx -s /dev/sda', 'lsblk -p', 'lscpu -J', 'free -b', 'uname -i',
#        'vmstat -SM', 'iostat -m', 'lslocks', 'lsmem', 'lsscsi',
#        'lshw -short', 'dmsetup ls', 'lsattr -R /data',
#        'find / -xdev -perm /u+s', 'chmod -R u-s /data',
#        'chown -R --from=root user /data', 'setfacl -R -b /data',
#        'chcon -u system_u file.txt', 'xxd -i file.txt',
#        'od -A d -t d4 file.bin', 'hexdump -C -n 16 file.bin',
#        "nl -w 2 -s ': ' file.txt", 'expand -t 4 file.txt',
#        'unexpand -t 4 file.txt', 'fmt -s file.txt', 'pr -d file.txt',
#        'fold -s -w 80 file.txt', 'cut -c 1-10 file.txt',
#        'sort -R file.txt', 'uniq -c file.txt',
#        'comm -12 file1.txt file2.txt', 'paste -s file.txt',
#        "join -t ',' file1.txt file2.txt", 'btrfs filesystem df /mnt',
#        'xfs_db -r /dev/sda1', 'debugfs -c /dev/sda1',
#        'dumpe2fs -h /dev/sda1', 'ethtool -i eth0', 'ip -j addr', 'ss -M',
#        'tcpdump -X -i eth0', 'nload eth0', 'ipcalc 192.168.1.0/24',
#        'perf record -p 1234', 'perf report', 'systemd-analyze blame',
#        'systemd-analyze critical-chain', 'journalctl -p 3 -b',
#        'lsns -t pid', 'findmnt -D', 'lsblk -J', 'dmidecode -t system',
#        'pidstat -d 1 3', 'systemctl list-dependencies nginx',
#        'systemctl is-enabled nginx', 'bpftool prog list',
#        'bpftool map list', 'trace-cmd record -p function -P 1234',
#        'trace-cmd report', 'fuser -k /var/log/syslog', 'lsof -t -i :80',
#        'etckeeper vcs log', 'mkswap /dev/sdb1', 'swapon /dev/sdb1',
#        'swapoff /dev/sdb1', 'cryptsetup luksDump /dev/sdb1',
#        'aa-complain /etc/apparmor.d/usr.sbin.nginx',
#        'aa-enforce /etc/apparmor.d/usr.sbin.nginx', 'nano -l config.conf',
#        'cd ..', 'dir', 'cp file.txt file.bak', 'mv file.txt /tmp',
#        'rm -i file.txt', 'cat -n script.sh', 'less +G logfile.txt',
#        'head -n 20 access.log', 'tail -n +2 error.log', 'cd -', 'ls -t',
#        'pwd -P', 'cp -p file.txt /backup', 'mv -i file.txt /tmp',
#        'rmdir /s /q dir1', 'touch -t 202505211200 file.txt',
#        'mkdir newdir', 'less +F logfile.txt', 'head -c 100 file.txt',
#        'tail -n 5 access.log', 'echo %PROCESSOR_ARCHITECTURE%',
#        'top -n 1', 'df -T', 'free -t', 'chmod 644 file.txt',
#        'chown -h user symlink', 'apt autoremove', 'apt purge nginx',
#        'yum remove httpd', 'dnf upgrade', 'netstat -i', 'who',
#        'net user newuser *', 'net user testuser /delete', 'ps -C nginx',
#        'killall nginx'], dtype=object)
